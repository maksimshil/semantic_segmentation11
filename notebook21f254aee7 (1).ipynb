# %% [markdown]
# # Install Packages and Import Libraries
#
# First, we have to install packages and import libraries to conduct image segmentation with PyTorch.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.__version__
import PIL
PIL.__version__
from PIL import Image
from glob import glob
import os
os.getcwd()
import cv2

import torch
torch.__version__
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
torchvision.__version__
from torchvision import transforms

# %%
# !pip install -U segmentation-models-pytorch
import segmentation_models_pytorch as smp
# Out:
# Requirement already satisfied: segmentation-models-pytorch in /opt/conda/lib/python3.10/site-packages (0.3.3)
# Requirement already satisfied: torchvision>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (0.16.2)
# Requirement already satisfied: pretrainedmodels==0.7.4 in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (0.7.4)
# Requirement already satisfied: efficientnet-pytorch==0.7.1 in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (0.7.1)
# Requirement already satisfied: timm==0.9.2 in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (0.9.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (4.66.1)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (9.5.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.1.2)
# Requirement already satisfied: munch in /opt/conda/lib/python3.10/site-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch) (4.0.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from timm==0.9.2->segmentation-models-pytorch) (6.0.1)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from timm==0.9.2->segmentation-models-pytorch) (0.22.2)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from timm==0.9.2->segmentation-models-pytorch) (0.4.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (2.31.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2024.2.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->timm==0.9.2->segmentation-models-pytorch) (21.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2024.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub->timm==0.9.2->segmentation-models-pytorch) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.3.0)

# %% [markdown]
# # Sample Images
#
# It is important to see one or several sample original images as well as annotated images. They can be shown in the same way and in a pair. In addition, we should check the data size of these images.

# %%
# original image
image = Image.open('/kaggle/input/12121212/dataset2/train/imgg/autosave01_02_2012_09_59_28_jpg.rf.b8d7c6125e9d2a03cbfea6f236d3d584.jpg')
image = np.array(image)
plt.imshow(image)

# %%
# label image
label = Image.open('/kaggle/input/12121212/dataset2/train/maskk/autosave01_02_2012_09_59_28_jpg.rf.b8d7c6125e9d2a03cbfea6f236d3d584_mask.png')
label = np.array(label)
plt.imshow(label)

# %%
image.shape, label.shape
# Out:
# ((640, 640, 3), (640, 640))

# %%
image.min(), image.max()
# Out:
# (0, 247)

# %%
label.min(), label.max()
# Out:
# (0, 10)

# %%
plt.figure(figsize = (9, 4))

plt.subplot(1, 2, 1)
plt.imshow(image)

plt.subplot(1, 2, 2)
plt.imshow(label)

# %% [markdown]
# # Create Dataset and Dataloader
#
# This is a typical sample code to create datasets to be used for training with PyTorch.

# %%
'''
class Dataset(torch.utils.data.Dataset):

    def __init__(self):
        self.images = sorted(glob('/kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/*.jpg'))
        self.labels = sorted(glob('/kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/*.png'))
        self.transform = transforms.Compose([ transforms.ToTensor() ])


    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path)
        image = self.transform(image)

        label_path = self.labels[idx]
        label = Image.open(label_path)
        label = np.array(label)
        label = torch.tensor(label, dtype = torch.int64)
        return image, label


    def __len__(self):
        return len(self.images)
'''
# Out:
# "\nclass Dataset(torch.utils.data.Dataset):\n\n    def __init__(self):\n        self.images = sorted(glob('/kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/*.jpg'))\n        self.labels = sorted(glob('/kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/*.png'))\n        self.transform = transforms.Compose([ transforms.ToTensor() ])\n\n\n    def __getitem__(self, idx):\n        image_path = self.images[idx]\n        image = Image.open(image_path)\n        image = self.transform(image)\n\n        label_path = self.labels[idx]\n        label = Image.open(label_path)\n        label = np.array(label)\n        label = torch.tensor(label, dtype = torch.int64)\n        return image, label\n\n\n    def __len__(self):\n        return len(self.images)\n"

# %%
class Dataset(torch.utils.data.Dataset):
    
      def __init__(
          self,
          transform = None,
          classes = None,
          augmentation = None
          ):
        self.imgpath_list = sorted(glob('/kaggle/input/datalast22/datalast/datalast/train/imgg/*.jpg'))
        self.labelpath_list = sorted(glob('/kaggle/input/datalast22/datalast/datalast/train/maskk/*.png'))

      def __getitem__(self, i):
                
        imgpath = self.imgpath_list[i]
        img = cv2.imread(imgpath)
        img = cv2.resize(img, dsize = (256, 256))
        img = img / 255
        img = torch.from_numpy(img.astype(np.float32)).clone()
        img = img.permute(2, 0, 1)

        labelpath = self.labelpath_list[i]
        label = Image.open(labelpath)
        label = np.asarray(label)
        label = cv2.resize(label, dsize = (256, 256))
        label = torch.from_numpy(label.astype(np.float32)).clone()
        label = torch.nn.functional.one_hot(label.long(), num_classes = len(class_list))
        label = label.to(torch.float32)
        label = label.permute(2, 0, 1)

        data = {"img": img, "label": label}
        return data

      def __len__(self):
            return len(self.imgpath_list)

# %%
dataset = Dataset()

# %%
train, val, test = torch.utils.data.random_split(dataset = dataset, lengths = [230, 31, 30], generator = torch.Generator().manual_seed(42))

len(train), len(val), len(test)
# Out:
# (230, 31, 30)

# %%
batch_size = 2

train_loader = torch.utils.data.DataLoader(train, batch_size, shuffle = True, drop_last = True)
val_loader = torch.utils.data.DataLoader(val, batch_size)
test_loader = torch.utils.data.DataLoader(test, batch_size)

# %% [markdown]
# # Create a Model
#
# We create an UNet model to learn segmentation tasks.

# %%
class TwoConvBlock(nn.Module):
    def __init__(self, in_channels, middle_channels, out_channels):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, middle_channels, kernel_size = 3, padding = "same")
        self.bn1 = nn.BatchNorm2d(middle_channels)
        self.rl = nn.ReLU()
        self.conv2 = nn.Conv2d(middle_channels, out_channels, kernel_size = 3, padding = "same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.rl(x)
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.rl(x)
        return x

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor = 2, mode = "bilinear", align_corners = True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding = "same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x

class UNet_2D(nn.Module):
    def __init__(self):
        super().__init__()
        self.TCB1 = TwoConvBlock(3, 64, 64)
        self.TCB2 = TwoConvBlock(64, 128, 128)
        self.TCB3 = TwoConvBlock(128, 256, 256)
        self.TCB4 = TwoConvBlock(256, 512, 512)
        self.TCB5 = TwoConvBlock(512, 1024, 1024)
        self.TCB6 = TwoConvBlock(1024, 512, 512)
        self.TCB7 = TwoConvBlock(512, 256, 256)
        self.TCB8 = TwoConvBlock(256, 128, 128)
        self.TCB9 = TwoConvBlock(128, 64, 64)
        self.maxpool = nn.MaxPool2d(2, stride = 2)
        
        self.UC1 = UpConv(1024, 512) 
        self.UC2 = UpConv(512, 256) 
        self.UC3 = UpConv(256, 128) 
        self.UC4= UpConv(128, 64)

        self.conv1 = nn.Conv2d(64, 24, kernel_size = 1)
        self.soft = nn.Softmax(dim = 1)

    def forward(self, x):
        x = self.TCB1(x)
        x1 = x
        x = self.maxpool(x)

        x = self.TCB2(x)
        x2 = x
        x = self.maxpool(x)

        x = self.TCB3(x)
        x3 = x
        x = self.maxpool(x)

        x = self.TCB4(x)
        x4 = x
        x = self.maxpool(x)

        x = self.TCB5(x)

        x = self.UC1(x)
        x = torch.cat([x4, x], dim = 1)
        x = self.TCB6(x)

        x = self.UC2(x)
        x = torch.cat([x3, x], dim = 1)
        x = self.TCB7(x)

        x = self.UC3(x)
        x = torch.cat([x2, x], dim = 1)
        x = self.TCB8(x)

        x = self.UC4(x)
        x = torch.cat([x1, x], dim = 1)
        x = self.TCB9(x)

        x = self.conv1(x)

        return x

# %%
def objective(trial):
    # Гиперпараметры, которые будем оптимизировать
    lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
    batch_size = trial.suggest_categorical('batch_size', [8, 16, 32])
    weight_decay = trial.suggest_loguniform('weight_decay', 1e-10, 1e-3)

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = UNet_2D().to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    BCELoss = smp.losses.SoftBCEWithLogitsLoss()
    TverskyLoss = smp.losses.TverskyLoss(mode='multilabel', log_loss=False)

    train_loader = DataLoader(...) # Настроить DataLoader
    val_loader = DataLoader(...)   # Настроить DataLoader

# %%
def criterion(pred, target):
        return 0.5 * BCELoss(pred, target) + 0.5 * TverskyLoss(pred, target)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
unet = UNet_2D().to(device)
optimizer = optim.Adam(unet.parameters(), lr = 0.0006552570182862688)

# %%
TverskyLoss = smp.losses.TverskyLoss(mode = 'multilabel', log_loss = False)
BCELoss     = smp.losses.SoftBCEWithLogitsLoss()
def criterion(pred,target):
    return 0.5 * BCELoss(pred, target) + 0.5 * TverskyLoss(pred, target)

# %%
history = {"train_loss": []}
n = 0
m = 0
val_loss_min = np.Inf
validation_accuracy = []
validation_loss = []

for epoch in range(15):
  train_accuracy = 0
  train_loss = 0
  val_accuracy = 0
  val_loss = 0
  correct_pixels = 0
  total_pixels = 0

# training
  unet.train()
  for i, data in enumerate(train_loader):
    inputs, labels = data["img"].to(device), data["label"].to(device)
    optimizer.zero_grad()
    outputs = unet(inputs)
    
    # pixel accuracy
    thresholded_outputs = (outputs > 0.5).int()
    correct_pixels = (thresholded_outputs == labels).sum().item()
    total_pixels += (inputs.size(2) * inputs.size(3)) * inputs.size(0)
    train_acc = correct_pixels / total_pixels
    train_accuracy += train_acc
    
    # loss
    loss = criterion(outputs, labels)
    labels = ['Actual', 'Label', 'Predicted']

    loss.backward()
    optimizer.step()
    train_loss += loss.item()
    history["train_loss"].append(loss.item())
    n += 1
    if i % ((len(train) // batch_size) // 10) == (len(train) // batch_size) // 10 - 1:
      print(f"epoch:{epoch + 1}  index:{i + 1}  train_accuracy:{train_accuracy / n:.5f}")
      print(f"epoch:{epoch + 1}  index:{i + 1}  train_loss:{train_loss / n:.5f}")
      n = 0
      train_accuracy = 0
      train_loss = 0

# validation
  unet.eval()
  with torch.no_grad():
    for i, data in enumerate(val_loader):
      inputs, labels = data["img"].to(device), data["label"].to(device)
      outputs = unet(inputs)
       
      # pixel accuracy
      thresholded_outputs = (outputs > 0.5).int()
      correct_pixels = (thresholded_outputs == labels).sum().item()
      total_pixels += (inputs.size(2) * inputs.size(3)) * inputs.size(0)
      val_acc = correct_pixels / total_pixels
      val_accuracy += val_acc  
       
      # loss
      loss = criterion(outputs, labels)
      val_loss += loss.item()
      m += 1
      if i % (len(val) // batch_size) == len(val) // batch_size - 1:
        print(f"epoch:{epoch + 1}  index:{i + 1}  validation_accuracy:{val_accuracy / m:.5f}")
        print(f"epoch:{epoch + 1}  index:{i + 1}  validation_loss:{val_loss / m:.5f}")
        validation_accuracy.append(val_accuracy)
        validation_loss.append(val_loss)
        if val_loss < val_loss_min:
            val_loss_min = val_loss
            torch.save(unet.state_dict(), 'semantic_segmentation.pt')
            print('Detected network improvement, saving current model')
        
        m = 0
        val_accuracy = 0
        val_loss = 0
        
print("finish training")
# Out:
# epoch:1  index:11  train_accuracy:5.57058
# epoch:1  index:11  train_loss:0.40535
# epoch:1  index:22  train_accuracy:1.28189
# epoch:1  index:22  train_loss:0.36010
# epoch:1  index:33  train_accuracy:0.79479
# epoch:1  index:33  train_loss:0.31063
# epoch:1  index:44  train_accuracy:0.58317
# epoch:1  index:44  train_loss:0.28433
# epoch:1  index:55  train_accuracy:0.45852
# epoch:1  index:55  train_loss:0.27054
# epoch:1  index:66  train_accuracy:0.38056
# epoch:1  index:66  train_loss:0.24181
# epoch:1  index:77  train_accuracy:0.32519
# epoch:1  index:77  train_loss:0.24610
# epoch:1  index:88  train_accuracy:0.28312
# epoch:1  index:88  train_loss:0.23025
# epoch:1  index:99  train_accuracy:0.24941
# epoch:1  index:99  train_loss:0.22954
# epoch:1  index:110  train_accuracy:0.22286
# epoch:1  index:110  train_loss:0.23319
# epoch:1  index:15  validation_accuracy:0.19039
# epoch:1  index:15  validation_loss:0.23100
# Detected network improvement, saving current model
# epoch:2  index:11  train_accuracy:4.44264
# epoch:2  index:11  train_loss:0.15587
# epoch:2  index:22  train_accuracy:1.42806
# epoch:2  index:22  train_loss:0.22702
# epoch:2  index:33  train_accuracy:0.84336
# epoch:2  index:33  train_loss:0.23520
# epoch:2  index:44  train_accuracy:0.60543
# epoch:2  index:44  train_loss:0.22602
# epoch:2  index:55  train_accuracy:0.47193
# epoch:2  index:55  train_loss:0.22395
# epoch:2  index:66  train_accuracy:0.38554
# epoch:2  index:66  train_loss:0.22374
# epoch:2  index:77  train_accuracy:0.32411
# epoch:2  index:77  train_loss:0.23283
# epoch:2  index:88  train_accuracy:0.28471
# epoch:2  index:88  train_loss:0.20701
# epoch:2  index:99  train_accuracy:0.24948
# epoch:2  index:99  train_loss:0.21724
# epoch:2  index:110  train_accuracy:0.22209
# epoch:2  index:110  train_loss:0.22670
# epoch:2  index:15  validation_accuracy:0.17860
# epoch:2  index:15  validation_loss:0.20714
# Detected network improvement, saving current model
# epoch:3  index:11  train_accuracy:4.41413
# epoch:3  index:11  train_loss:0.15296
# epoch:3  index:22  train_accuracy:1.43249
# epoch:3  index:22  train_loss:0.21373
# epoch:3  index:33  train_accuracy:0.84273
# epoch:3  index:33  train_loss:0.22411
# epoch:3  index:44  train_accuracy:0.60598
# epoch:3  index:44  train_loss:0.21678
# epoch:3  index:55  train_accuracy:0.47271
# epoch:3  index:55  train_loss:0.21320
# epoch:3  index:66  train_accuracy:0.38480
# epoch:3  index:66  train_loss:0.22404
# epoch:3  index:77  train_accuracy:0.32697
# epoch:3  index:77  train_loss:0.21440
# epoch:3  index:88  train_accuracy:0.28153
# epoch:3  index:88  train_loss:0.22382
# epoch:3  index:99  train_accuracy:0.24979
# epoch:3  index:99  train_loss:0.21542
# epoch:3  index:110  train_accuracy:0.22421
# epoch:3  index:110  train_loss:0.21496
# epoch:3  index:15  validation_accuracy:0.17867
# epoch:3  index:15  validation_loss:0.20240
# Detected network improvement, saving current model
# epoch:4  index:11  train_accuracy:4.42698
# epoch:4  index:11  train_loss:0.14261
# epoch:4  index:22  train_accuracy:1.42426
# epoch:4  index:22  train_loss:0.21396
# epoch:4  index:33  train_accuracy:0.84864
# epoch:4  index:33  train_loss:0.21523
# epoch:4  index:44  train_accuracy:0.60557
# epoch:4  index:44  train_loss:0.21056
# epoch:4  index:55  train_accuracy:0.47283
# epoch:4  index:55  train_loss:0.20265
# epoch:4  index:66  train_accuracy:0.38592
# epoch:4  index:66  train_loss:0.21147
# epoch:4  index:77  train_accuracy:0.32603
# epoch:4  index:77  train_loss:0.21243
# epoch:4  index:88  train_accuracy:0.28426
# epoch:4  index:88  train_loss:0.20428
# epoch:4  index:99  train_accuracy:0.24978
# epoch:4  index:99  train_loss:0.21206
# epoch:4  index:110  train_accuracy:0.22344
# epoch:4  index:110  train_loss:0.21265
# epoch:4  index:15  validation_accuracy:0.17880
# epoch:4  index:15  validation_loss:0.19825
# Detected network improvement, saving current model
# epoch:5  index:11  train_accuracy:4.41447
# epoch:5  index:11  train_loss:0.13973
# epoch:5  index:22  train_accuracy:1.43225
# epoch:5  index:22  train_loss:0.21220
# epoch:5  index:33  train_accuracy:0.85090
# epoch:5  index:33  train_loss:0.20678
# epoch:5  index:44  train_accuracy:0.60461
# epoch:5  index:44  train_loss:0.21602
# epoch:5  index:55  train_accuracy:0.47150
# epoch:5  index:55  train_loss:0.21389
# epoch:5  index:66  train_accuracy:0.38657
# epoch:5  index:66  train_loss:0.20642
# epoch:5  index:77  train_accuracy:0.32599
# epoch:5  index:77  train_loss:0.21197
# epoch:5  index:88  train_accuracy:0.28234
# epoch:5  index:88  train_loss:0.21366
# epoch:5  index:99  train_accuracy:0.24923
# epoch:5  index:99  train_loss:0.21640
# epoch:5  index:110  train_accuracy:0.22366
# epoch:5  index:110  train_loss:0.21302
# epoch:5  index:15  validation_accuracy:0.17887
# epoch:5  index:15  validation_loss:0.19374
# Detected network improvement, saving current model
# epoch:6  index:11  train_accuracy:4.45445
# epoch:6  index:11  train_loss:0.13619
# epoch:6  index:22  train_accuracy:1.43738
# epoch:6  index:22  train_loss:0.20106
# epoch:6  index:33  train_accuracy:0.84972
# epoch:6  index:33  train_loss:0.20952
# epoch:6  index:44  train_accuracy:0.60018
# epoch:6  index:44  train_loss:0.21462
# epoch:6  index:55  train_accuracy:0.47054
# epoch:6  index:55  train_loss:0.21297
# epoch:6  index:66  train_accuracy:0.38500
# epoch:6  index:66  train_loss:0.20989
# epoch:6  index:77  train_accuracy:0.32788
# epoch:6  index:77  train_loss:0.19559
# epoch:6  index:88  train_accuracy:0.28118
# epoch:6  index:88  train_loss:0.22232
# epoch:6  index:99  train_accuracy:0.24964
# epoch:6  index:99  train_loss:0.20813
# epoch:6  index:110  train_accuracy:0.22498
# epoch:6  index:110  train_loss:0.19471
# epoch:6  index:15  validation_accuracy:0.17843
# epoch:6  index:15  validation_loss:0.19853
# epoch:7  index:11  train_accuracy:4.44240
# epoch:7  index:11  train_loss:0.12549
# epoch:7  index:22  train_accuracy:1.43863
# epoch:7  index:22  train_loss:0.19434
# epoch:7  index:33  train_accuracy:0.84489
# epoch:7  index:33  train_loss:0.21464
# epoch:7  index:44  train_accuracy:0.60336
# epoch:7  index:44  train_loss:0.21248
# epoch:7  index:55  train_accuracy:0.46947
# epoch:7  index:55  train_loss:0.21082
# epoch:7  index:66  train_accuracy:0.38602
# epoch:7  index:66  train_loss:0.20093
# epoch:7  index:77  train_accuracy:0.32853
# epoch:7  index:77  train_loss:0.19453
# epoch:7  index:88  train_accuracy:0.28404
# epoch:7  index:88  train_loss:0.19493
# epoch:7  index:99  train_accuracy:0.24851
# epoch:7  index:99  train_loss:0.19732
# epoch:7  index:110  train_accuracy:0.22392
# epoch:7  index:110  train_loss:0.20227
# epoch:7  index:15  validation_accuracy:0.17757
# epoch:7  index:15  validation_loss:0.20766
# epoch:8  index:11  train_accuracy:4.44300
# epoch:8  index:11  train_loss:0.14097
# epoch:8  index:22  train_accuracy:1.43668
# epoch:8  index:22  train_loss:0.19129
# epoch:8  index:33  train_accuracy:0.84999
# epoch:8  index:33  train_loss:0.19620
# epoch:8  index:44  train_accuracy:0.60297
# epoch:8  index:44  train_loss:0.20521
# epoch:8  index:55  train_accuracy:0.47201
# epoch:8  index:55  train_loss:0.19655
# epoch:8  index:66  train_accuracy:0.38554
# epoch:8  index:66  train_loss:0.20239
# epoch:8  index:77  train_accuracy:0.32633
# epoch:8  index:77  train_loss:0.20645
# epoch:8  index:88  train_accuracy:0.28250
# epoch:8  index:88  train_loss:0.20517
# epoch:8  index:99  train_accuracy:0.25008
# epoch:8  index:99  train_loss:0.19779
# epoch:8  index:110  train_accuracy:0.22466
# epoch:8  index:110  train_loss:0.19561
# epoch:8  index:15  validation_accuracy:0.17843
# epoch:8  index:15  validation_loss:0.19603
# epoch:9  index:11  train_accuracy:4.43232
# epoch:9  index:11  train_loss:0.13197
# epoch:9  index:22  train_accuracy:1.43731
# epoch:9  index:22  train_loss:0.19076
# epoch:9  index:33  train_accuracy:0.84426
# epoch:9  index:33  train_loss:0.20818
# epoch:9  index:44  train_accuracy:0.60675
# epoch:9  index:44  train_loss:0.19601
# epoch:9  index:55  train_accuracy:0.47128
# epoch:9  index:55  train_loss:0.20266
# epoch:9  index:66  train_accuracy:0.38433
# epoch:9  index:66  train_loss:0.20618
# epoch:9  index:77  train_accuracy:0.32903
# epoch:9  index:77  train_loss:0.18814
# epoch:9  index:88  train_accuracy:0.28179
# epoch:9  index:88  train_loss:0.20642
# epoch:9  index:99  train_accuracy:0.25061
# epoch:9  index:99  train_loss:0.19426
# epoch:9  index:110  train_accuracy:0.22393
# epoch:9  index:110  train_loss:0.20090
# epoch:9  index:15  validation_accuracy:0.17771
# epoch:9  index:15  validation_loss:0.20238
# epoch:10  index:11  train_accuracy:4.43728
# epoch:10  index:11  train_loss:0.13863
# epoch:10  index:22  train_accuracy:1.43439
# epoch:10  index:22  train_loss:0.19981
# epoch:10  index:33  train_accuracy:0.84880
# epoch:10  index:33  train_loss:0.20090
# epoch:10  index:44  train_accuracy:0.60530
# epoch:10  index:44  train_loss:0.20583
# epoch:10  index:55  train_accuracy:0.47314
# epoch:10  index:55  train_loss:0.18168
# epoch:10  index:66  train_accuracy:0.38626
# epoch:10  index:66  train_loss:0.19289
# epoch:10  index:77  train_accuracy:0.32729
# epoch:10  index:77  train_loss:0.19381
# epoch:10  index:88  train_accuracy:0.28265
# epoch:10  index:88  train_loss:0.19117
# epoch:10  index:99  train_accuracy:0.24993
# epoch:10  index:99  train_loss:0.20195
# epoch:10  index:110  train_accuracy:0.22402
# epoch:10  index:110  train_loss:0.19242
# epoch:10  index:15  validation_accuracy:0.17883
# epoch:10  index:15  validation_loss:0.18590
# Detected network improvement, saving current model
# epoch:11  index:11  train_accuracy:4.46010
# epoch:11  index:11  train_loss:0.12762
# epoch:11  index:22  train_accuracy:1.43259
# epoch:11  index:22  train_loss:0.19688
# epoch:11  index:33  train_accuracy:0.84541
# epoch:11  index:33  train_loss:0.20998
# epoch:11  index:44  train_accuracy:0.60716
# epoch:11  index:44  train_loss:0.19375
# epoch:11  index:55  train_accuracy:0.47118
# epoch:11  index:55  train_loss:0.19678
# epoch:11  index:66  train_accuracy:0.38640
# epoch:11  index:66  train_loss:0.19704
# epoch:11  index:77  train_accuracy:0.32716
# epoch:11  index:77  train_loss:0.19407
# epoch:11  index:88  train_accuracy:0.28222
# epoch:11  index:88  train_loss:0.20710
# epoch:11  index:99  train_accuracy:0.25021
# epoch:11  index:99  train_loss:0.18800
# epoch:11  index:110  train_accuracy:0.22406
# epoch:11  index:110  train_loss:0.19022
# epoch:11  index:15  validation_accuracy:0.17894
# epoch:11  index:15  validation_loss:0.18153
# Detected network improvement, saving current model
# epoch:12  index:11  train_accuracy:4.42497
# epoch:12  index:11  train_loss:0.14357
# epoch:12  index:22  train_accuracy:1.43204
# epoch:12  index:22  train_loss:0.18977
# epoch:12  index:33  train_accuracy:0.85193
# epoch:12  index:33  train_loss:0.18339
# epoch:12  index:44  train_accuracy:0.60592
# epoch:12  index:44  train_loss:0.19148
# epoch:12  index:55  train_accuracy:0.47195
# epoch:12  index:55  train_loss:0.18588
# epoch:12  index:66  train_accuracy:0.38566
# epoch:12  index:66  train_loss:0.19440
# epoch:12  index:77  train_accuracy:0.32921
# epoch:12  index:77  train_loss:0.17436
# epoch:12  index:88  train_accuracy:0.28377
# epoch:12  index:88  train_loss:0.17927
# epoch:12  index:99  train_accuracy:0.24922
# epoch:12  index:99  train_loss:0.20269
# epoch:12  index:110  train_accuracy:0.22395
# epoch:12  index:110  train_loss:0.19656
# epoch:12  index:15  validation_accuracy:0.17909
# epoch:12  index:15  validation_loss:0.17945
# Detected network improvement, saving current model
# epoch:13  index:11  train_accuracy:4.44285
# epoch:13  index:11  train_loss:0.13058
# epoch:13  index:22  train_accuracy:1.43472
# epoch:13  index:22  train_loss:0.19049
# epoch:13  index:33  train_accuracy:0.84823
# epoch:13  index:33  train_loss:0.19462
# epoch:13  index:44  train_accuracy:0.60704
# epoch:13  index:44  train_loss:0.17941
# epoch:13  index:55  train_accuracy:0.47308
# epoch:13  index:55  train_loss:0.18225
# epoch:13  index:66  train_accuracy:0.38526
# epoch:13  index:66  train_loss:0.19686
# epoch:13  index:77  train_accuracy:0.32676
# epoch:13  index:77  train_loss:0.18752
# epoch:13  index:88  train_accuracy:0.28443
# epoch:13  index:88  train_loss:0.18541
# epoch:13  index:99  train_accuracy:0.24985
# epoch:13  index:99  train_loss:0.19264
# epoch:13  index:110  train_accuracy:0.22412
# epoch:13  index:110  train_loss:0.19159
# epoch:13  index:15  validation_accuracy:0.17894
# epoch:13  index:15  validation_loss:0.18058
# epoch:14  index:11  train_accuracy:4.44045
# epoch:14  index:11  train_loss:0.13614
# epoch:14  index:22  train_accuracy:1.43893
# epoch:14  index:22  train_loss:0.17935
# epoch:14  index:33  train_accuracy:0.85171
# epoch:14  index:33  train_loss:0.18736
# epoch:14  index:44  train_accuracy:0.60742
# epoch:14  index:44  train_loss:0.19029
# epoch:14  index:55  train_accuracy:0.47209
# epoch:14  index:55  train_loss:0.18095
# epoch:14  index:66  train_accuracy:0.38589
# epoch:14  index:66  train_loss:0.19148
# epoch:14  index:77  train_accuracy:0.32544
# epoch:14  index:77  train_loss:0.19536
# epoch:14  index:88  train_accuracy:0.28448
# epoch:14  index:88  train_loss:0.18139
# epoch:14  index:99  train_accuracy:0.25056
# epoch:14  index:99  train_loss:0.18976
# epoch:14  index:110  train_accuracy:0.22349
# epoch:14  index:110  train_loss:0.18568
# epoch:14  index:15  validation_accuracy:0.17874
# epoch:14  index:15  validation_loss:0.18276
# epoch:15  index:11  train_accuracy:4.46543
# epoch:15  index:11  train_loss:0.12160
# epoch:15  index:22  train_accuracy:1.43810
# epoch:15  index:22  train_loss:0.18840
# epoch:15  index:33  train_accuracy:0.84561
# epoch:15  index:33  train_loss:0.20189
# epoch:15  index:44  train_accuracy:0.60492
# epoch:15  index:44  train_loss:0.19964
# epoch:15  index:55  train_accuracy:0.46960
# epoch:15  index:55  train_loss:0.18748
# epoch:15  index:66  train_accuracy:0.38556
# epoch:15  index:66  train_loss:0.18853
# epoch:15  index:77  train_accuracy:0.32862
# epoch:15  index:77  train_loss:0.17482
# epoch:15  index:88  train_accuracy:0.28451
# epoch:15  index:88  train_loss:0.18209
# epoch:15  index:99  train_accuracy:0.25119
# epoch:15  index:99  train_loss:0.17883
# epoch:15  index:110  train_accuracy:0.22439
# epoch:15  index:110  train_loss:0.18276
# epoch:15  index:15  validation_accuracy:0.17916
# epoch:15  index:15  validation_loss:0.17345
# Detected network improvement, saving current model
# finish training

# %%
# !pip install optuna
import optuna
import optuna.visualization as vis
import torch
from torch import nn, optim
from torch.utils.data import DataLoader

# Не забудьте определить ваш датасет и наш train и val датасеты
# Например:
# train = YourTrainDataset()
# val = YourValDataset()

def objective(trial):
    # Suggest hyperparameters
    lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
    batch_size = trial.suggest_categorical('batch_size', [2, 4, 8, 16])
    n_filters = 4

    # Setup data loaders
    train_loader = DataLoader(train, batch_size, shuffle=True, drop_last=True)
    val_loader = DataLoader(val, batch_size)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Initialize the model with suggested number of filters
    model = UNet_2D().to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    # Initialize metrics
    num_epochs = 10
    val_loss_min = float('inf')
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        
        for data in train_loader:
            inputs, labels = data["img"].to(device), data["label"].to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        model.eval()
        val_accuracy = 0
        val_loss = 0
        with torch.no_grad():
            m = 0
            for data in val_loader:
                inputs, labels = data["img"].to(device), data["label"].to(device)
                outputs = model(inputs)
                val_loss += criterion(outputs, labels).item()
                m += 1
                
                thresholded_outputs = (outputs > 0.5).int()
                val_accuracy += (thresholded_outputs == labels).sum().item() / (inputs.size(2) * inputs.size(3) * inputs.size(0))
                
        val_loss /= m
        val_accuracy /= m
        
        trial.report(val_loss, epoch)
        
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()
        
        if val_loss < val_loss_min:
            val_loss_min = val_loss
            torch.save(model.state_dict(), 'semantic_segmentation.pt')
    
    return val_loss_min


study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

print('Best hyperparameters:', study.best_trial.params)


fig = vis.plot_param_importances(study)
fig.show()

fig = vis.plot_optimization_history(study)
fig.show()

fig = vis.plot_parallel_coordinate(study)
fig.show()

fig = vis.plot_contour(study)
fig.show()

fig = vis.plot_slice(study)
fig.show()

fig = vis.plot_edf(study)
fig.show()
# Out:
# Requirement already satisfied: optuna in /opt/conda/lib/python3.10/site-packages (3.6.1)
# Requirement already satisfied: alembic>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.10/site-packages (from optuna) (6.8.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from optuna) (21.3)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from optuna) (2.0.25)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (1.3.3)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->optuna) (3.1.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/conda/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# [I 2024-06-02 15:24:28,743] A new study created in memory with name: no-name-d4c4b261-8e6c-43e5-b186-f73dfc7befda
# /tmp/ipykernel_34/3160290433.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# [I 2024-06-02 15:26:49,862] Trial 0 finished with value: 0.9937133640050888 and parameters: {'lr': 0.04872591443143352, 'batch_size': 8}. Best is trial 0 with value: 0.9937133640050888.
# [I 2024-06-02 15:29:21,129] Trial 1 finished with value: 0.8930482752621174 and parameters: {'lr': 7.730960033944049e-05, 'batch_size': 2}. Best is trial 1 with value: 0.8930482752621174.
# [I 2024-06-02 15:31:44,182] Trial 2 finished with value: 1.4501901268959045 and parameters: {'lr': 5.751591202052474e-05, 'batch_size': 8}. Best is trial 1 with value: 0.8930482752621174.
# [I 2024-06-02 15:33:56,814] Trial 3 finished with value: 0.8903399705886841 and parameters: {'lr': 0.001161186754696173, 'batch_size': 16}. Best is trial 3 with value: 0.8903399705886841.
# [I 2024-06-02 15:36:19,756] Trial 4 finished with value: 0.8581411764025688 and parameters: {'lr': 0.0003070489688482039, 'batch_size': 4}. Best is trial 4 with value: 0.8581411764025688.
# [I 2024-06-02 15:36:33,150] Trial 5 pruned.
# [I 2024-06-02 15:37:01,793] Trial 6 pruned.
# [I 2024-06-02 15:37:15,073] Trial 7 pruned.
# [I 2024-06-02 15:39:36,947] Trial 8 finished with value: 0.807178545743227 and parameters: {'lr': 0.0007872967197731515, 'batch_size': 4}. Best is trial 8 with value: 0.807178545743227.
# [I 2024-06-02 15:40:07,060] Trial 9 pruned.
# [I 2024-06-02 15:40:21,346] Trial 10 pruned.
# [I 2024-06-02 15:42:43,978] Trial 11 finished with value: 0.8465431705117226 and parameters: {'lr': 0.0004842994617641435, 'batch_size': 4}. Best is trial 8 with value: 0.807178545743227.
# [I 2024-06-02 15:45:05,835] Trial 12 finished with value: 0.8738748729228973 and parameters: {'lr': 0.003948938143431051, 'batch_size': 4}. Best is trial 8 with value: 0.807178545743227.
# [I 2024-06-02 15:45:34,310] Trial 13 pruned.
# [I 2024-06-02 15:46:31,559] Trial 14 pruned.
# [I 2024-06-02 15:48:55,719] Trial 15 finished with value: 0.8235038407146931 and parameters: {'lr': 0.0007050252927762014, 'batch_size': 4}. Best is trial 8 with value: 0.807178545743227.
# [W 2024-06-02 15:49:24,027] Trial 16 failed with parameters: {'lr': 0.010781786986142277, 'batch_size': 4} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_34/3160290433.py", line 55, in objective
#     outputs = model(inputs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/tmp/ipykernel_34/1120487147.py", line 61, in forward
#     x = self.TCB2(x)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/tmp/ipykernel_34/1120487147.py", line 12, in forward
#     x = self.bn1(x)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/batchnorm.py", line 177, in forward
#     self.running_var if not self.training or self.track_running_stats else None,
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1685, in __getattr__
#     if name in _parameters:
# KeyboardInterrupt
# [W 2024-06-02 15:49:24,034] Trial 16 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[128], line 78
#      74     return val_loss_min
#      77 study = optuna.create_study(direction='minimize')
# ---> 78 study.optimize(objective, n_trials=50)
#      80 print('Best hyperparameters:', study.best_trial.params)
#      83 fig = vis.plot_param_importances(study)
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:62, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60 try:
#      61     if n_jobs == 1:
# ---> 62         _optimize_sequential(
#      63             study,
#      64             func,
#      65             n_trials,
#      66             timeout,
#      67             catch,
#      68             callbacks,
#      69             gc_after_trial,
#      70             reseed_sampler_rng=False,
#      71             time_start=None,
#      72             progress_bar=progress_bar,
#      73         )
#      74     else:
#      75         if n_jobs == -1:
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In[128], line 55, in objective(trial)
#      53 for data in val_loader:
#      54     inputs, labels = data["img"].to(device), data["label"].to(device)
# ---> 55     outputs = model(inputs)
#      56     val_loss += criterion(outputs, labels).item()
#      57     m += 1
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[122], line 61, in UNet_2D.forward(self, x)
#      58 x1 = x
#      59 x = self.maxpool(x)
# ---> 61 x = self.TCB2(x)
#      62 x2 = x
#      63 x = self.maxpool(x)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[122], line 12, in TwoConvBlock.forward(self, x)
#      10 def forward(self, x):
#      11     x = self.conv1(x)
# ---> 12     x = self.bn1(x)
#      13     x = self.rl(x)
#      14     x = self.conv2(x)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/batchnorm.py:177, in _BatchNorm.forward(self, input)
#     164     bn_training = (self.running_mean is None) and (self.running_var is None)
#     166 r"""
#     167 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     168 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     169 used for normalization (i.e. in eval mode when buffers are not None).
#     170 """
#     171 return F.batch_norm(
#     172     input,
#     173     # If buffers are not to be tracked, ensure that they won't be updated
#     174     self.running_mean
#     175     if not self.training or self.track_running_stats
#     176     else None,
# --> 177     self.running_var if not self.training or self.track_running_stats else None,
#     178     self.weight,
#     179     self.bias,
#     180     bn_training,
#     181     exponential_average_factor,
#     182     self.eps,
#     183 )
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1685, in Module.__getattr__(self, name)
#    1683 if '_parameters' in self.__dict__:
#    1684     _parameters = self.__dict__['_parameters']
# -> 1685     if name in _parameters:
#    1686         return _parameters[name]
#    1687 if '_buffers' in self.__dict__:
#
# KeyboardInterrupt:

# %% [markdown]
# # Training and Validation Loss
#
# We visualize the transition of the accuracy and loss during the training.

# %%
plt.title("Train Loss")
plt.plot(history["train_loss"])
plt.xlabel('batch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
plt.title("Validation Accuracy")
plt.plot(validation_accuracy)
plt.xlabel('num_epochs', fontsize = 12)
plt.ylabel('accuracy', fontsize = 12)
# Out:
# Text(0, 0.5, 'accuracy')

# %%
plt.title("Validation Loss")
plt.plot(validation_loss)
plt.xlabel('num_epochs', fontsize = 12)
plt.ylabel('loss', fontsize = 12)
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# # Load the Best Model

# %%
# import the trained network with the best loss of validation
unet.load_state_dict(torch.load('semantic_segmentation.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Prediction and Comparison with the Truth
#
# We can compare the original images, annotated images, and predicted images to evaluate the performance by the trained segmentation model.

# %%
model = UNet_2D()
model.load_state_dict(torch.load("semantic_segmentation.pt"))
model.eval()
with torch.no_grad():
  data = next(iter(test_loader))
  inputs, labels = data["img"], data["label"]
  outputs = model(inputs)
  loss = criterion(outputs, labels)
  print("Loss: ", loss.item())

  thresholded_outputs = (outputs > 0.5).int()
  intersection = torch.logical_and(thresholded_outputs, labels).sum(dim = [1, 2, 3]).float()
  union = torch.logical_or(thresholded_outputs, labels).sum(dim = [1, 2, 3]).float()
  iou_score = (intersection / union).mean().item()
  print("Intersection over Union:", iou_score)
  
  dice_score = ((2 * intersection) / (thresholded_outputs.sum(dim=[1, 2, 3]) + labels.sum(dim=[1, 2, 3]))).mean().item()
  print("Dice coefficient:", dice_score)


sigmoid = nn.Sigmoid()
outputs = sigmoid(outputs)
pred = torch.argmax(outputs, axis = 1)
pred = torch.nn.functional.one_hot(pred.long(), num_classes = len(class_list)).to(torch.float32)
# Out:
# Loss:  0.1613231748342514
# Intersection over Union: 0.7468205690383911
# Dice coefficient: 0.8529496192932129

# %%
plt.figure()
plt.imshow(data["img"][1, :, :, :].permute(1, 2, 0))

plt.title("original_image")
plt.axis("off")
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torchvision.transforms.functional import to_pil_image
from matplotlib.colors import ListedColormap

# Подготовка модели к работе
model = UNet_2D()
model.load_state_dict(torch.load("semantic_segmentation.pt"))
model.eval()

# Сгенерировать цвета для каждого класса
num_classes = len(class_list)
colors = plt.cm.get_cmap('tab20', num_classes)  # Получение цветовой карты с num_classes цветами

# Обработка тестовых данных
with torch.no_grad():
    data = next(iter(test_loader))
    inputs, labels = data["img"], data["label"]
    outputs = model(inputs)
    
    sigmoid = nn.Sigmoid()
    outputs = sigmoid(outputs)
    
    # Получение предсказаний для каждого класса
    pred = torch.argmax(outputs, axis=1)
    
    # Создаем цветное изображение масок
    pred_color = colors(pred[2].cpu().numpy())  # Преобразуем значения в цвета с помощью выбранной цветовой карты
    pred_color_image = pred_color[..., :3]  # Удалить альфа-канал
    
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.imshow(to_pil_image(inputs[2]))
    plt.title("Original Image")
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(pred_color_image)  # Отображение цветного изображения предсказаний
    plt.title('Predicted Masks Combined')
    plt.axis('off')

    plt.show()
# Out:
# /tmp/ipykernel_34/666325080.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab20', num_classes)  # Получение цветовой карты с num_classes цветами
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[138], line 29
#      26 pred = torch.argmax(outputs, axis=1)
#      28 # Создаем цветное изображение масок
# ---> 29 pred_color = colors(pred[2].cpu().numpy())  # Преобразуем значения в цвета с помощью выбранной цветовой карты
#      30 pred_color_image = pred_color[..., :3]  # Удалить альфа-канал
#      32 plt.figure(figsize=(12, 6))
#
# IndexError: index 2 is out of bounds for dimension 0 with size 2

# %%
import matplotlib.pyplot as plt
import torch
import time
import torch.nn as nn
from torchvision.transforms.functional import to_pil_image
from matplotlib.colors import ListedColormap

# Подготовка модели к работе
model = UNet_2D()
model.load_state_dict(torch.load("semantic_segmentation.pt"))
model.eval()
start_time = time.time()
# Сгенерировать цвета для каждого класса
num_classes = len(class_list)
colors = plt.cm.get_cmap('tab20', num_classes)  # Получение цветовой карты с num_classes цветами

num_batches = 5  # Установка числа батчей для отображения
images_per_batch =2  # Количество изображений для отображения в каждом батче

fig, axes = plt.subplots(num_batches, images_per_batch * 2, figsize=(12, num_batches * 6))

for batch_idx, data in enumerate(test_loader):
    if batch_idx >= num_batches:
        break
    inputs, labels = data["img"], data["label"]
    outputs = model(inputs)
    
    sigmoid = nn.Sigmoid()
    outputs = sigmoid(outputs)
    
    # Получение предсказаний для каждого класса
    pred = torch.argmax(outputs, axis=1)

    for img_idx in range(images_per_batch):
        # Original image
        axes[batch_idx, img_idx * 2].imshow(to_pil_image(inputs[img_idx]))
        axes[batch_idx, img_idx * 2].set_title("Original Image")
        axes[batch_idx, img_idx * 2].axis('off')

        # Predicted mask
        pred_color = colors(pred[img_idx].cpu().numpy())
        pred_color_image = pred_color[..., :3]  # Удалить альфа-канал
        axes[batch_idx, img_idx * 2 + 1].imshow(pred_color_image)
        axes[batch_idx, img_idx * 2 + 1].set_title('Predicted Masks Combined')
        axes[batch_idx, img_idx * 2 + 1].axis('off')
        
end_time = time.time()
segmentation_time = end_time - start_time
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_34/3951019284.py:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab20', num_classes)  # Получение цветовой карты с num_classes цветами

# %%
classes = class_list
fig, ax = plt.subplots(2, 6, figsize = (15, 8))
for j, cl in enumerate(classes[6:12]):
    if i == 0 and j < 6:
        ax[i, j].imshow(pred[0, :, :, j])
        ax[i, j].set_title(f"pred_{cl}")
        ax[i, j].axis("off")
    elif j < 6:
        ax[i, j].imshow(data["label"][0, j, :, :])    
        ax[i, j].set_title(f"label_{cl}")
        ax[i, j].axis("off")

# %%
classes = class_list
fig, ax = plt.subplots(2, 6, figsize = (15, 8))
for i in range(2):
    for j, cl in enumerate(classes[12:18]):
        if i == 0 and j < 6:
            ax[i, j].imshow(pred[0, :, :, j])
            ax[i, j].set_title(f"pred_{cl}")
            ax[i, j].axis("off")
        elif j < 6:
            ax[i, j].imshow(data["label"][0, j, :, :])    
            ax[i, j].set_title(f"label_{cl}")
            ax[i, j].axis("off")

# %%
classes = class_list
fig, ax = plt.subplots(2, 6, figsize = (15, 8))
for i in range(2):
    for j, cl in enumerate(classes[18:]):
        if i == 0 and j < 6:
            ax[i, j].imshow(pred[0, :, :, j])
            ax[i, j].set_title(f"pred_{cl}")
            ax[i, j].axis("off")
        elif j < 6:
            ax[i, j].imshow(data["label"][0, j, :, :])    
            ax[i, j].set_title(f"label_{cl}")
            ax[i, j].axis("off")
